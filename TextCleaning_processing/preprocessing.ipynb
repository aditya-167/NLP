# %% [markdown]
# ### Processing & Cleaning

# %%
data = "https://raw.githubusercontent.com/laxmimerit/twitter-data/master/twitter4000.csv"

# %%
import pandas as pd
import numpy as np
import spacy as sp

# %%
df = pd.read_csv(data)

# %%
df.head()
# Out:
#                                               twitts  sentiment
# 0  is bored and wants to watch a movie  any sugge...          0
# 1           back in miami.  waiting to unboard ship           0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                  ughhh i am so tired  blahhhhhhhhh          0
# 4  @mandagoforth me bad! It's funny though. Zacha...          0

# %%
df = df.rename(columns={"twitts":"tweets"})

# %%
from spacy.lang.en.stop_words import STOP_WORDS as stopwords

# %%
df['sentiment'].value_counts()
# Out:
# 1    2000
# 0    2000
# Name: sentiment, dtype: int64

# %% [markdown]
# ### Word Counts

# %%
len('this is text'.split())
# Out:
# 3

# %%
df['word_counts'] = df['tweets'].apply(lambda x:len(str(x).split()))

# %%
df.head(10)
# Out:
#                                               tweets  sentiment  word_counts
# 0  is bored and wants to watch a movie  any sugge...          0           10
# 1           back in miami.  waiting to unboard ship           0            7
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0           12
# 3                  ughhh i am so tired  blahhhhhhhhh          0            6
# 4  @mandagoforth me bad! It's funny though. Zacha...          0           26
# 5  brr, i'm so cold. at the moment doing my assig...          0           17
# 6  @kevinmarquis haha yep but i really need to sl...          0           22
# 7  eating some ice-cream while I try to see @pete...          0           14
# 8            @phatty84 just hella bored at work  lol          0            7
# 9                           Food poisoning blowssss           0            3

# %%
df.word_counts.max(),df.word_counts.min()
# Out:
# (32, 1)

# %%
df[df.word_counts==1]
# Out:
#                                tweets  sentiment  word_counts
# 385                         homework           0            1
# 691                         @ekrelly           0            1
# 1124                    disappointed           0            1
# 1286                 @officialmgnfox           0            1
# 1325                        headache           0            1
# 1897                      @MCRmuffin           0            1
# 2542                      Graduated!           1            1
# 2947                         reading           1            1
# 3176                    @omeirdeleon           1            1
# 3470  www.myspace.com/myfinalthought           1            1
# 3966                        @gethyp3           1            1

# %% [markdown]
# ### Character Count

# %%
def char_counts(x):
    ####TO skip white spaces####
    s = x.split()
    x = ''.join(s)
    return len(x)

# %%
df['char_counts'] = df.tweets.apply(lambda x : char_counts(str(x)))

# %%
df.head(10)
# Out:
#                                               tweets  sentiment  word_counts  \
# 0  is bored and wants to watch a movie  any sugge...          0           10
# 1           back in miami.  waiting to unboard ship           0            7
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0           12
# 3                  ughhh i am so tired  blahhhhhhhhh          0            6
# 4  @mandagoforth me bad! It's funny though. Zacha...          0           26
# 5  brr, i'm so cold. at the moment doing my assig...          0           17
# 6  @kevinmarquis haha yep but i really need to sl...          0           22
# 7  eating some ice-cream while I try to see @pete...          0           14
# 8            @phatty84 just hella bored at work  lol          0            7
# 9                           Food poisoning blowssss           0            3
#
#    char_counts
# 0           43
# 1           32
# 2           54
# 3           27
# 4          116
# 5           87
# 6           94
# 7           88
# 8           32
# 9           21

# %% [markdown]
# ### Average word length

# %%
df['avg_word_length'] = df.char_counts/df.word_counts

# %%
df.sample(5)
# Out:
#                                                  tweets  sentiment  \
# 1684  Bradley still woke up crying with sore throat,...          0
# 1056  Okay I Was Going To Sleep; But Isabella's Cryi...          0
# 305                 I have a torn something in my knee           0
# 3660      @gtrbush SENT YOU SOME PICS CHECK YOUR EMAIL           1
# 1341     @leylacarter Me gusta Twittear dejameeeeeeeee           0
#
#       word_counts  char_counts  avg_word_length
# 1684           20           92            4.600
# 1056           12           48            4.000
# 305             8           27            3.375
# 3660            8           37            4.625
# 1341            5           41            8.200

# %% [markdown]
# ### Stop Words Count

# %%
print(stopwords)
# Out:
# {'we', 'whose', 'say', 'therein', 'perhaps', 'therefore', 'and', 'whereas', 'empty', 'mine', 'has', 'would', 'unless', 'been', 'seems', 'until', 'latter', 'for', 'him', 'in', 'fifteen', 'thereupon', 'yourself', "'d", 'eleven', 'moreover', 'elsewhere', 'top', 'noone', 'have', 'her', 'being', 'at', 'below', 'besides', 'nothing', 'along', 'now', 'nine', 'could', 'other', 'enough', 'mostly', 'be', 'part', 'others', 'everyone', 'someone', 'always', 'various', 'whether', 'who', 'either', 'again', "'ve", 'herself', 'well', 'hers', 'except', 'even', 'else', 'same', 'what', 'own', 'upon', 'were', 'least', 'toward', 'last', 'somehow', "'ll", 'call', 'she', 'anyway', 'give', 'once', 'around', 'not', 'become', 'does', 'somewhere', 'whereupon', 'whither', '‘s', 'eight', 'neither', 'by', 'doing', '‘m', 'hundred', 'almost', 'to', 'none', 'sometimes', 'really', '’ve', "n't", 'if', 'one', 'bottom', 'might', 'whereafter', 'keep', 'via', 'seem', 'latterly', 'otherwise', 'up', 'amongst', 'it', 'themselves', 'can', 'than', 'nevertheless', 'back', 'also', 'six', 'whenever', '’m', 'down', 'us', 'twelve', 'take', 'since', 'formerly', 'whereby', 'forty', 'three', '‘re', 'ten', 'full', 'towards', 'did', '‘d', 'anyhow', 'becoming', 'very', 'a', 'much', 'four', 'only', 'itself', 'became', '‘ll', 'had', 'serious', 'whence', 'often', 'few', 'throughout', '’re', 'show', 'next', 'make', 'anyone', 'such', 'both', 'beyond', 'thereafter', 'without', 'so', 'on', 'side', 'n‘t', 'yet', 'those', '’ll', "'m", 'how', 'where', 'herein', 'just', 'whatever', 'n’t', 'more', 'sometime', 'see', 'however', 'done', 'behind', '’s', 'seeming', 'do', 'something', 'ca', 'under', 'nobody', 'while', 'over', 'our', 'against', 'name', 'alone', 'when', 'though', 'or', 'further', 'every', 'but', 'five', 'my', 'quite', 'hereupon', 'should', 'them', 'wherever', 'that', 'ever', 'this', 'first', 'made', 'thus', 'any', 'becomes', 'these', 're', 'is', 'there', 'move', 'they', 'no', 'amount', 'among', 'i', 'after', 'here', 'some', 'then', 'go', 'which', 'am', 'across', 'fifty', 'twenty', 'anywhere', 'his', 'put', 'whom', 'their', 'together', "'s", 'beside', 'several', 'used', 'everywhere', 'off', 'still', 'before', 'former', 'of', 'afterwards', 'your', 'due', 'front', 'will', 'everything', 'less', 'may', "'re", 'nowhere', 'already', 'through', 'many', 'the', 'thru', 'an', 'thence', 'most', '‘ve', 'above', 'you', 'are', 'hereafter', 'never', 'out', 'indeed', 'ourselves', 'seemed', 'why', 'hence', 'although', 'wherein', 'hereby', 'per', 'himself', 'third', '’d', 'whoever', 'rather', 'myself', 'me', 'during', 'yourselves', 'was', 'whole', 'thereby', 'into', 'namely', 'regarding', 'another', 'please', 'onto', 'must', 'yours', 'nor', 'anything', 'its', 'using', 'about', 'two', 'from', 'sixty', 'all', 'as', 'with', 'between', 'because', 'too', 'within', 'meanwhile', 'get', 'ours', 'beforehand', 'each', 'cannot', 'he'}

# %%
len(stopwords)
# Out:
# 326

# %%
df['stop_words_count'] = df['tweets'].apply(lambda x : len(list(t for t in x.split() if t in stopwords)))

# %%
df.sample(5)
# Out:
#                                                  tweets  sentiment  \
# 465   just got computer back but i still need to tak...          0
# 1464  i dont like the heat anymore  im sooo tired &a...          0
# 696   Iï¿½m in Valencia (Spain) in my house...Iï¿½m ...          0
# 2416  @chrisdrackett My new portfoliodesign will mak...          1
# 341   Primavera all morning. Bugs in the system = gr...          0
#
#       word_counts  char_counts  avg_word_length  stop_words
# 465            13           49         3.769231          10
# 1464           13           57         4.384615           3
# 696             8           47         5.875000           3
# 2416           12           73         6.083333           4
# 341            18           84         4.666667           7

# %% [markdown]
# ### Count # Tags and @ Mentions

# %%
df['hashtags_count'] = df.tweets.apply(lambda x : len(list(t  for t in x.split() if t.startswith('#'))))

# %%
df['mention_count'] = df.tweets.apply(lambda x : len(list(t  for t in x.split() if t.startswith('@'))))

# %%
df.sample(7)
# Out:
#                                                  tweets  sentiment  \
# 442   @DexterAddict Oh pls share when you've made su...          0
# 3133  just had my daily Loose Women fix although it ...          1
# 3038  @run350 Girl, U outta see it. LOL I have 3 awk...          1
# 2570          @LexiThaBoss Thanx babe. Love back 2 you           1
# 2196  Had a good night out last night after work. Lo...          1
# 2665  @stokely @johubris @andrewbarnett thanks, you ...          1
# 959   Zomg - totally came into work 30 mins early. I...          0
#
#       word_counts  char_counts  avg_word_length  stop_words  hashtags_count  \
# 442            15           69         4.600000           4               0
# 3133           16           75         4.687500           7               0
# 3038           27          111         4.111111           8               0
# 2570            7           34         4.857143           2               0
# 2196           24          114         4.750000          11               0
# 2665            6           45         7.500000           1               0
# 959            20           71         3.550000           8               0
#
#       mention_count
# 442               1
# 3133              1
# 3038              1
# 2570              1
# 2196              0
# 2665              3
# 959               0

# %% [markdown]
# ### Numeric digit check!

# %%
df['numeric_count'] = df.tweets.apply(lambda x : len(list(t for t in x.split() if t.isdigit())))

# %%
df.sample(6)
# Out:
#                                                  tweets  sentiment  \
# 3556  @djbriancua yeah thats a good start. back then...          1
# 2352  my brother sleeps long,might go swimming 2day ...          1
# 3511  Hey @songzyuuup yessssssssssssssssssssssss   (...          1
# 1816  @roxanne_ong 12 more days? so fast... i'm gonn...          0
# 1821  I did it! Went to sleep before 12....unfortuna...          0
# 411   @mikefoong @hantu  Unfortunately, that Friday ...          0
#
#       word_counts  char_counts  avg_word_length  stop_words  hashtags_count  \
# 3556           28          109         3.892857          12               0
# 2352           16           81         5.062500           4               0
# 3511            7           79        11.285714           0               0
# 1816           11           49         4.454545           2               0
# 1821           22           90         4.090909          13               0
# 411            17           97         5.705882           5               0
#
#       mention_count  numeric_count
# 3556              1              2
# 2352              0              1
# 3511              1              0
# 1816              1              1
# 1821              0              0
# 411               2              0

# %% [markdown]
# ### Letter cases

# %%
df['upper_case_count'] = df.tweets.apply(lambda x: len(list(t for t in x.split() if t.isupper())))

# %%
df['tweets'] = df['tweets'].apply(lambda x:str(x).lower())

# %%
df.sample(5)
# Out:
#                                                  tweets  sentiment  \
# 13    padres come back from being down 6-0 &amp; we ...          0
# 3712                                 eating chocolates           1
# 2632                    the cake looks amazing al pink           1
# 1375  all the managers are gone today!!! yay! i thin...          0
# 713   why oh why did i volunteer to write my final a...          0
#
#       word_counts  char_counts  avg_word_length  stop_words  hashtags_count  \
# 13             18           82         4.555556           8               0
# 3712            2           16         8.000000           0               0
# 2632            6           25         4.166667           0               0
# 1375           15           57         3.800000           8               0
# 713            23           96         4.173913           9               0
#
#       mention_count  numeric_count  upper_case_count
# 13                0              0                 0
# 3712              0              0                 0
# 2632              0              0                 0
# 1375              0              0                 0
# 713               0              1                 0

# %% [markdown]
# ### count and remove Emails

# %%
import re

# %%
x = '@ghas is # tabea @ajsam.com,as r adityasrichandan3098@gmail.com,mdaw-0fa'

# %%
re.findall(r'([a-z0-9._-]+@[a-z0-9._-]+\.[a-z0-9_-]+)',x)
# Out:
# ['adityasrichandan3098@gmail.com']

# %%
df['emails'] = df.tweets.apply(lambda x : re.findall(r'([a-z0-9._-]+@[a-z0-9._-]+\.[a-z0-9_-]+\b)',x))

# %%
df['emails_count'] = df.emails.apply(lambda x:len(x))

# %%
df.sample(20)
# Out:
#                                                  tweets  sentiment  \
# 1612  @shaycarl i'm gonna make  you a banner out of ...          0
# 1318  gots golf in the morning. i love the sport but...          0
# 309   merlot rocks, but the wife doesn't like the sc...          0
# 2736  @kkrseattle @jmedero  either gonna be ac or p ...          1
# 2116  @caseybrothers nope holding a nice hot cup of ...          1
# 344                @reminiscesmith im only on 1800  lol          0
# 2497  #ff keep an eye on the claw and the new u2 tou...          1
# 3080                        hooray,.. it's saturday..!           1
# 2799                             new phone tomorrow!!!           1
# 207                found out i have a throat infection           0
# 3684  what happened to mileys best friend leslie? or...          1
# 1695  @mmitchelldaviss  i'm sorry mitchell! that sucks!          0
# 1192  @tatylicous i wanted to dance with you awwwww ...          0
# 1267  @irenekoehler but darnnit we didn't get to con...          0
# 2893  @realmattlucas thanks matt- falling around lau...          1
# 926   goodmorning twitter land. getting all the kidd...          0
# 1371  @cinnamoncloud nope!  can't get a signal... mi...          0
# 1363  cannot get up this morn. must be the thought o...          0
# 1816  @roxanne_ong 12 more days? so fast... i'm gonn...          0
# 349   i remember when friday nights were about takin...          0
#
#       word_counts  char_counts  avg_word_length  stop_words  hashtags_count  \
# 1612           24          108         4.500000          10               0
# 1318           21           75         3.571429          13               0
# 309            14           64         4.571429           5               0
# 2736           15           73         4.866667           4               0
# 2116           12           57         4.750000           4               0
# 344             6           30         5.000000           2               0
# 2497           26          106         4.076923          12               1
# 3080            3           24         8.000000           0               0
# 2799            3           19         6.333333           0               0
# 207             7           29         4.142857           4               0
# 3684           21           89         4.238095           8               0
# 1695            6           43         7.166667           1               0
# 1192           27          111         4.111111          10               0
# 1267           10           60         6.000000           4               0
# 2893            9           57         6.333333           3               0
# 926            24          109         4.541667          12               0
# 1371           11           59         5.363636           5               0
# 1363           20           75         3.750000          10               0
# 1816           11           49         4.454545           2               0
# 349            24          107         4.458333          10               0
#
#       mention_count  numeric_count  upper_case_count emails  emails_count
# 1612              1              0                 2     []             0
# 1318              0              0                 1     []             0
# 309               0              0                 0     []             0
# 2736              2              0                 2     []             0
# 2116              1              0                 0     []             0
# 344               1              1                 0     []             0
# 2497              2              0                 1     []             0
# 3080              0              0                 0     []             0
# 2799              0              0                 0     []             0
# 207               0              0                 0     []             0
# 3684              0              0                 0     []             0
# 1695              1              0                 0     []             0
# 1192              1              0                 4     []             0
# 1267              1              0                 0     []             0
# 2893              1              0                 0     []             0
# 926               0              0                 0     []             0
# 1371              1              0                 0     []             0
# 1363              0              1                 0     []             0
# 1816              1              1                 0     []             0
# 349               0              0                 3     []             0

# %%
df[df['emails_count']>0]
# Out:
#                                                  tweets  sentiment  \
# 3713  @securerecs arghh me please  markbradbury_16@h...          1
#
#       word_counts  char_counts  avg_word_length  stop_words  hashtags_count  \
# 3713            5           51             10.2           0               0
#
#       mention_count  numeric_count  upper_case_count  \
# 3713              1              0                 0
#
#                              emails  emails_count
# 3713  [markbradbury_16@hotmail.com]             1

# %%
df['emails'] = df.tweets.apply(lambda x : re.sub(r'([a-z0-9._-]+@[a-z0-9._-]+\.[a-z0-9_-]+\b)'," ",x))

# %%
df[df['emails_count']>0].tweets
# Out:
# 3713    @securerecs arghh me please  markbradbury_16@h...
# Name: tweets, dtype: object
